# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math


import mesa
from mesa.datacollection import DataCollector
from mesa import Model,Agent
from mesa.space import MultiGrid
from mesa.experimental.cell_space import CellAgent, FixedAgent, OrthogonalVonNeumannGrid
from mesa.experimental.devs import ABMSimulator
from mesa.visualization import Slider, SolaraViz, make_plot_component, make_space_component
#.model for all times you want to look at all the grid at a time point, .grid for all grid fucntions and no

# %%
#This cell is used for the base class of bronchial
class Bronchial(CellAgent):
    def __init__(self, model, pos, init_health =100): #put in all the baseline values we want,
        super().__init__(model)
        self.init_health = init_health #initial health of bronchial
        self.health = init_health
        self.pos = pos
        #self.schedule_event(self.replacement, at=7.0)

    
    #def placement(self):
        
    #healing rate mechanism - note we have healing and replinishment?
    def healing(self):
        for obj in self.cell.neighborhood:
            bound_bacteria=False
            for obj in cell.agents:
                if isinstance(obj,Pathogen):
                    bound_bacteria=True
                    break
        if (bound_bacteria==False) and (self.health<(self.init_health/2)):
            self.health+=1

    #replenisment rate mechanism
    def replacement(self):
        #find how long it takes to replace itself
        for cell in self.cell.neighborhood: #looks at all the neighbooring cells
            bound_bacteria=False
            for obj in cell.agents: #looks at all the agents in a cell like they were a list
                if isinstance(obj,Pathogen):
                    bound_bacteria=True
                    break
        if (bound_bacteria==False) and self.health>(self.init_health*.75):
            self.new_pos = (self.pos[0]+1,self.pos[1])
            self.__class__(self.model,self.cell,self.health,self.new_pos)

    #in infected state, it will call macrophages, and secrete more mucus
    def call_macro(self): # move when it spawns
        x = self.random.randrange(self.model.grid.width)
        y = self.random.randrange(2)
        pos = (x,y)
        self.model.call_macro(pos)

    def call_mucin(self): #secretes mucin in infected state
        pos=(self.pos[0],self.pos[1]+1)
        self.model.call_mucin(pos)

    #idk if we wanna put it here or with the pathogen but this code can be used to make it lose a certain amout of health based on whats stuck to it?
    def health_loss(self):
        bronch_space = self.model.grid.get_neighbors(self.pos, moore= False)
        bact_no = 0
        bact_no = sum(1 for obj in bronch_space if isinstance(obj, Pathogen) == True)

    #what happens each step
    def step(self):
        self.health_loss
        if self.health > 75 and self.model.step_count%2==0:
            infect_int = 3 # redo this part to have mltiple stages
            self.call_macro()
            for i in range(infect_int):
                self.call_mucin()
        #if health <= 0: #cell death
            #self.remove()
        #elif health <= #value for it to trigger healing? which in turns calls mucus:

# %%
#this cell is used for the base class of the bacteria and biofilm

class Pathogen(CellAgent):
    def __init__(self, model, pos, health = 100, strength = 10, bacteria_gain= 10, p_rep = 0.04, p_unstick = 0.04, biof_formed = False):
        super().__init__(model)
        self.pos = pos
        self.health = health #lifespan of pathogen
        self.strength = strength #how much damage it deals to brocnhial
        self.bacteria_gain = bacteria_gain #how much "health" bacteria gains from bronchiol damage
        self.p_rep = p_rep #probability to trigger reproduction
        self.p_unstick = p_unstick #probability of bacteria in biofilm to "unstick" from biofilm
        self.biof_formed = biof_formed #if the specific bacteria is part of the biofilm or not


    #movement - random, limited by mucus, but evasion of macrophages
    def move_bacteria(self):
        self.model.grid.move_agent(self, (self.pos[0],self.pos[1]+1))

    #movement of bacteria affected by cilia - rn its copied off the mucin one lol
    def move_cilia(self):
        for i in range(12): # moves cilia right 12 times * we might need to move this part to step
            self.model.grid.move_agent(self, (self.pos[0]-1,self.pos[1]))

    #damaging the bronchiol - cell loses healt, brionchial gains health
    def atk_bacteria(self):
        return
        bronchiol_present = lambda cell: any(isinstance(obj, Bronchial) for obj in cell.agent)
        if bronchiol_present.available:
            self.health += bacteria_gain
            Bronchial.health -=self.strength
            #notee  that we need to re do this without the cell.agent command


    #biofilm formation upon contact with other bacteria
    def biofilm_formation(self):
        return
        #idea before implementation - model biofilm by just makeing them stick to each other and then increasing the health by a certain ffactor when x amount is present and maybe
        #we can also model it to have a certain step strength in a random direction that will decrease the more are connected? and we can have antibiotic deal damage exactly as large as the health or say it insta kills it vs deald this mich dMG when not insta kill
        #model prob of unstick with liek if random is (p sunstick then it will detach)
        bacteria_present = lambda cell: any(isinstance(obj, Pathogen)for obj in cell.agent)
        #note that we need to not do this with cell.agent


        #code to model bacteria stikcing together in biofilm
        if bacteria.present.available and (self.biof_formed == False):
            #insert code here lol
            self.biof_formed = True

        #probability of bacteria to stop sticking to biofilm
        if (self.biof_formed== True) and (self.random.random() < self.p_unstick):
            #insert code here lol
            self.biof_formed = False



    #reproduction rate of bacteria
    def spawn_offspring(self):
        #using half of its health, it can spawn offspring
        self.health /= 2
        new_bac= Pathogen(self.model, self.pos, self.cell,self.health, self.bacteria_gain, p_rep)
        #self.model.grid.place_agent(new_bac, self.pos)


    #what happens each step
    def step_bacteria(self):
        self.move_bacteria()
        self.biofilm_formation()
        self.atk_bacteria()
        #bacterial death or reproduction
        if self.health < 0:
            return
            #self.remove()
        elif self.random.random() < self.p_rep :
            self.spawn_offspring()

# %%
#this cell is used for the base class of the mucin, which is an important component of mucus
class Mucin(CellAgent):
    def __init__(self, model, pos):
        super().__init__(model)
        self.pos = pos
        #viscosity as parameter to multiple stuff by? or we set it as a probablity and timestep of killing rando, mucus
    #mucus acts as a medium for the antibiotics, pathogens, and macrophages to travel

    #movement of mucus through cilia
    def move_cilia(self):
            for i in range(12): # moves cilia right 12 times * we might need to move this part to step
                self.model.grid.move_agent(self, (self.pos[0]-1,self.pos[1])) # multiply that moevemt later when u can based on healtj
        #inflammation (bronchiol health dec) will decrease movement 
    
        #after cilia pushes, muscin will try to spread out randomly/ normal level muscin will replenish
        #insert code for random 2d movemtn


    #clearance of mucus through cough - fix oth movements to moveout and get deletdtt
    def move_cough(self):
        #define how much "agents" get moved in one cough, needs same clearance boundaries as move cilia
        self.model.grid.move_agent(self, (self.pos[0]-2, self.pos[1]))

    def ciliaspaw(self): # move when it spawns
        y=self.random.choice([3,4])
        pos=(19,y)
        self.model.gen_cilia(pos)
        
    def mucin_spread(self): # if we need this function, a way to ensure only a max no, of mucin is in one squre ( will probably fry karolinas laptop when mucin is high lowk)
        #might want to be in model funct not here 

        #will count values of mucin in one space
        muc_space = self.model.grid.get_cell_list_contents([self.pos])
        muc_no = 0
        muc_no = sum(1 for obj in muc_space if isinstance(obj, Mucin) == True)
        #this ensures that not too much mucin is found in one place, im thinking if we wanna limit health to infect mucin layer, we can just change the if to have a variable that can hsange
        if muc_no < 5:
            muc_surround = self.model.grid.get_neighborhood(self.pos, moore = True)
            #if any(isinstance(obj, Bronchial) for obj in muc_surround): - idk if this one works lowkey
            if self.pos[1] == 3:
                x = self.pos[0]
                y = self.pos[1]
                possible_directions = [(x,y), (x+1,y), (x-1, y), (x+1, y+1), (x-1, y+1), (x,y+1)] # this is so it doesnt go down if its in the first lane
                muc_spread_pos = self.random.choice(possible_directions)
                self.model.grid.move_agent(self, muc_spread_pos)
                #move anywhere but down
            else:
                muc_spread_pos = self.random.choice(muc_surround)
                self.model.grid.move_agent(self, muc_spread_pos)
            
            #this line of code is to determine if the "mucin went too far" if it dd it will "fall ?"
            muc_test = self.model.grid.get_neighbors(self.pos, moore = True, radius= 2)
            if (len(muc_test) < 10) and (self.pos[1] != 3):
                self.model.grid.move_agent(self, (self.pos[0], self.pos[1]-1 ))
                #this works but it seems to be causing lag, everything else i did didnt


            #self.model.grid.move_agent(self, (self.pos[0]-2, self.pos[1]))
            
            #self.viscosity = 0.2
            #use this value to spread mucin properly + use to decide viscosity 
                #if muc> 5 : viscosity = 1 , 0.5, 0.4 - > multiply dorectly into movement
                

    #what happens each step
    def step(self):
        # lol rn its spwning like 100000 and causing rlly slow runtime - current fix is return all func 
        bronch_health_check = list(self.model.agents_by_type[Bronchial])
        for b in bronch_health_check: #change this so that it will trigger if any of them 
            #idk if this will wokr but im thinking of running each b in an if statement then add it to a new variable, then use those that variable 
            #next question is if we want a certain no of injured ones to trigger it multiple times or no
            if b.health > 75: # healthy state of body. temporary health value
                if  (self.pos[0] ==0): 
                    self.remove()
                    self.ciliaspaw()
                    return
                else:
                    self.move_cilia()
                    return
            elif b.health < 75: #temporary vhealth value
                if self.model.step_count > 5: #only in infected state
                    if self.model.random.random() < 0.5:
                        if  (self.pos[0] == 1 or self.pos[0] == 0):
                            self.remove()
                            return
                        else:
                            self.move_cough()
                            return
        self.mucin_spread()

# %%
#this cell is used for the base class of the macrophage
class Macrophage(CellAgent):
    def __init__(self, model, pos, health = 20,strength = 20, macrophage_gain= 15, p_rep = 0.04):
        super().__init__(model)
        self.pos = pos
        self.health = health
        self.strength = strength
        self.macrophage_gain = macrophage_gain
        self.p_rep = p_rep

    #movement - aims for the bacteria
    def move_macrophage(self):
        #macrophage will move within mucin
        findneighbors = self.model.grid.get_neighbors(self.pos,True,False)
        pathogen_found_list=[]
        distances=[]
        for agent in findneighbors:
            if isinstance(agent,Mucin):
                distances.append(agent.pos[1])
                maxmucin=max(distances)
            else:
                maxmucin=self.pos[1]
        
        if self.pos[1]>2 and self.pos[1]<=maxmucin: #I dont want them to leave the mucin but they in theory shouldnt as long at there is bacteria near by we could limit them to the tallest mucin with get all cells find the farthest distance with get distance and based on that put an if condition, but we can see
            for obj in findneighbors:
                if isinstance(obj, Pathogen):
                    pathogen_found=obj.pos
                    pathogen_found_list.append(pathogen_found)
        #do we want random movement? if yes, i think this needs to go in a diff if, else line
            if len(pathogen_found_list)>0:
                self.model.grid.move_agent_to_one_of(self,pathogen_found_list)
            else:
                getnearpositions=self.model.grid.get_neighborhood(self.pos,True, False)
                self.model.grid.move_agent_to_one_of(self,getnearpositions)
        elif self.pos[1]<=2 and self.pos[1]<=maxmucin:
                self.model.grid.move_agent(self,(self.pos[0],self.pos[1]+1)) 
                #for now its in step 0 but since they will only be called during infection that shouldnt be a problem
        else:
            return
        
        #call list of neighbors - if any r pathogen it will 

        #also include if its under epithelial that it will go up only to get it out of theer (if possible limit where it can go)


    def spawn_rep(self): #mechanism for macrophages to increase through replication
        pass
 


    #what happens each step
    def step(self):
        self.move_macrophage()
        self.health -=1 #will moving and cntact decrease health?
        #remove when health is 0
        #reproduction mechanism

# %%
#this cell is used for the base class of antibiotics
class Antibiotic(CellAgent):
    def __init__(self, model,pos, health = 15, strength = 10,):
        super().__init__(model)
        self.pos = pos
        self.health = health
        self.strength = strength

    def move_anti(self):
        pass

    def step(self):
        self.move_anti()
        self.health -= 1 #in this case this is how long it lasts in the body
        #cell remobe here when health is gone
        #reproduction mechanism

# %%
#this cell is used for the creation of the model, which creates the grid
class LungModel(Model):
    def __init__(self, width=20, height=20, init_health_Bronchial=100, seed=100, simulator=None):
        super().__init__(seed=seed)
        self.simulator = simulator
        self.simulator.setup(self)
        self.grid = MultiGrid(width, height, torus=True)
        self.step_count=0
        reporters = {
            "Mucin": lambda m: len(m.agents_by_type[Mucin]),
            "Bronchial": lambda m: len(m.agents_by_type[Bronchial]),
            "Pathogen": lambda m: len(m.agents_by_type[Pathogen]),
            "Antibiotic": lambda m: len(m.agents_by_type[Antibiotic]),
            "Macrophage": lambda m: len(m.agents_by_type[Macrophage])

        }
        self.datacollector = DataCollector(reporters)


        #set the fixed position of the bronchial layer
        for x in range(width):
            epithelial=Bronchial(
                self,
                (x,2),
                init_health = init_health_Bronchial,
                ) #makes 20 of the bronchial, the ali form makes batches of randomly placed
            self.grid.place_agent(epithelial, (x,2))

        #initial mucin consists of 1 layer, then the rest is randomized
        
        for x in range(width):
            y=self.random.choice([3,4])
            mucus_layer= Mucin(self,(x,y),)
            self.grid.place_agent(mucus_layer,(x,y))

        self.total_mucin = 20
        while self.total_mucin != 50:
            for y in range(3,5):
                x = self.random.randrange(self.grid.width)
                mucus_layer= Mucin(self,(x,y),)
                self.total_mucin+=1 #ramdon placement within first line
                self.grid.place_agent(mucus_layer,(x,y))


        total_bact = 0
        total_macro = 0
        while total_bact != 10 : #code to spawn the bacteria within bounds of mucus
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            if any(isinstance(agent, Mucin) for agent in self.grid[x][y]): # might need to change this to be a range of the grid w mucin in it
                total_bact+=1
                bacteria = Pathogen(
                    self,
                    pos = (x,y),
                    health = 100,
                    strength = 10,
                    bacteria_gain= 10,
                    p_rep = 0.04,
                    p_unstick = 0.04,
                    biof_formed = False,
                    )
                self.grid.place_agent(bacteria, (x,y))

        while total_macro != 5 : #code to spawn the macro within bounds of mucus
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            if any(isinstance(agent, Mucin) for agent in self.grid[x][y]):
                total_macro+=1
                macrophages = Macrophage(
                    self,
                    pos = (x,y),
                    health = 20,
                    strength = 20,
                    macrophage_gain = 15,
                    p_rep = 0.04,
                    )
                self.grid.place_agent(macrophages, (x,y))

        for x in range(width):
            antibiotic = Antibiotic(
                self,
                (x,1),
                health = 15,
                strength= 10,
                )
            self.grid.place_agent(antibiotic, (x,1))
        #needs to be in model because in agent it does it does every step for every agent
        #I wonder if there is a way to know the hieght of the tallest mucin like its y position
        

        # functions to call agents from other agents

    def gen_cilia(self,pos):
        #while self.mucin_gen != 12:
            y=self.random.choice([3,4])
            pos=(19,y)
                 #i wonder if there is a way to alter this depending on how much mucin hieght in the y direction 
            new_mu = Mucin(self,pos)
            self.grid.place_agent(new_mu, pos)
            #self.mucin_gen+=1


       #calling macrophages in infected state
    def call_macro(self,pos): #function to call macrophages from bloodstream in cell injury
        x = self.random.randrange(self.grid.width)
        y = self.random.randrange(2)
        pos = (x,y)
        new_macro = Macrophage(self,pos,
                    health = 20,
                    strength = 20,
                    macrophage_gain = 15,
                    p_rep = 0.04,)
        self.grid.place_agent(new_macro, pos)
        
    def call_mucin(self,pos): #secretes mucin in infected state
        new_mu = Mucin(self,pos=pos)
        self.grid.place_agent(new_mu,pos=pos)


            
                

# think abt bc for stopping mucus at bronchior

#set the initial position of antibiotics


    def step(self):
        self.step_count+=1
        #self.mucin_gen=0
        self.agents_by_type[Bronchial].shuffle_do("step")
        self.agents_by_type[Mucin].shuffle_do("step")
        self.agents_by_type[Pathogen].shuffle_do("step")
        self.agents_by_type[Antibiotic].shuffle_do("step")
        self.agents_by_type[Macrophage].shuffle_do("step")
        self.datacollector.collect(self)

# %%
# Styling for visualization
AGENT_COLORS = {
    "Bronchial": "#FD7D7B",
    "Mucin": "green",
    "Pathogen": "blue",
    "Antibiotic": "black",
    "Macrophage": "purple"
}

# Change these parameters to experiment with the model!
MODEL_PARAMETERS = {
    "width": 20, # Grid width
    "height": 20, # Grid height
    #this is wher eu would put the parameter s(if we had any)
    "bronchial_init_health": 100, # heaalth of bironchil
    "seed": 100, # Random seed for reproducibility
}
def lung_portrayal(agent):
    if agent is None:
        return
    p = {"size": 25}
    if isinstance(agent, Mucin):
        p.update({"color": AGENT_COLORS["Mucin"], "marker": "o", "zorder": 3, "size": 45}) #zorder = positioning of whihc is the tip layer
    elif isinstance(agent, Bronchial):
        p.update({"color": AGENT_COLORS["Bronchial"], "marker": "o", "zorder": 60})
    elif isinstance(agent, Pathogen):
        p.update({"color": AGENT_COLORS["Pathogen"], "marker": "o", "zorder": 4, "size" : 25})
    elif isinstance(agent, Antibiotic):
        p.update({"color": AGENT_COLORS["Antibiotic"], "marker": "o", "zorder": 4, "size" : 25})
    elif isinstance(agent, Macrophage):
        p.update({"color": AGENT_COLORS["Macrophage"], "marker": "o", "zorder": 4, "size" : 25})

    return p

model_params = {
    "width": 20,
    "height": 20,
    "bronchial_init_health": Slider("Initial Health of Bronchiol", MODEL_PARAMETERS["bronchial_init_health"], 10, 300),
}

simulator = ABMSimulator()
model_instance = LungModel(simulator=simulator)
space_component = make_space_component(lung_portrayal, draw_grid=True)
lineplot_component = make_plot_component({
    "Bronchial": AGENT_COLORS["Bronchial"],
    "Mucin": AGENT_COLORS["Mucin"],
    "Pathogen": AGENT_COLORS["Pathogen"],
    "Antibiotic": AGENT_COLORS["Antibiotic"],
    "Macrophage": AGENT_COLORS["Macrophage"]
})

page = SolaraViz(
    model_instance,
    components=[space_component, lineplot_component],
    model_params=model_params,
    simulator=simulator,
)
page
# Out:
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (10, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (13, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (14, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (15, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (16, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (17, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (19, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (10, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# Cannot show ipywidgets in text

# %%
import matplotlib.pyplot as plt

# Change these parameters to experiment with the model!
MODEL_PARAMETERS = {
    "width": 20, # Grid width
    "height": 20, # Grid height
    #this is wher eu would put the parameter s(if we had any)
    "init_health_Bronchial": 100, # heaalth of bironchil
    "seed": 100, # Random seed for reproducibility
}

# Change this value to run the simulation for more or fewer steps
steps_to_run = 10

print(f"Running simulation for {steps_to_run} steps...")

backup_simulator = ABMSimulator()

# New model instance separate from the one used in the SolaraViz
backup_model = LungModel(
    simulator=backup_simulator,
    **MODEL_PARAMETERS
)

# for _ in range(steps_to_run):
#     backup_model.step()

backup_simulator.run_for(steps_to_run)

df = backup_model.datacollector.get_model_vars_dataframe()

plt.figure(figsize=(12, 6))

plt.plot(df.index, df["Mucin"], color=AGENT_COLORS["Mucin"], label="Mucin", linewidth=2.5)
plt.plot(df.index, df["Bronchial"], color=AGENT_COLORS["Bronchial"], label="Bronchiol", linewidth=2.5)
plt.plot(df.index, df["Pathogen"], color=AGENT_COLORS["Pathogen"], label="Pathogen", linewidth=2.5)
plt.plot(df.index, df["Macrophage"], color=AGENT_COLORS["Macrophage"], label="Macrophage", linewidth=2.5)
plt.plot(df.index, df["Antibiotic"], color=AGENT_COLORS["Antibiotic"], label="Antibiotic", linewidth=2.5)


# Formatting
plt.title("Gut Infection ABM: Population Dynamics")
plt.xlabel("Time (Steps)")
plt.ylabel("Population Count")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1)) # Puts legend outside the plot
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Display the plot
plt.show()

# TIP: To save this image for your PDF, right-click the plot and select "Save image as..."
# Alternatively, uncomment the line below to save it directly to your folder:
# plt.savefig("my_time_series.png", dpi=300)
# Out:
# Running simulation for 10 steps...
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (10, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (13, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (14, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (15, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (16, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (17, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:27: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (19, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (10, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:34: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:42: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:62: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:77: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:86: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (10, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 152 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 153 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 154 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 155 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 156 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 157 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 158 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 159 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 160 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 161 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 162 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 163 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 164 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 165 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# ...
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 539 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 540 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 541 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 542 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 543 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 544 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 545 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 546 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 547 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 548 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 549 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 550 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 551 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 552 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 553 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 554 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 555 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 556 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 557 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 558 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 559 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 560 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 561 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 562 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 563 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 564 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 565 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 566 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 567 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 568 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 569 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 570 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 571 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 572 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 573 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 574 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 575 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 576 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:113: UserWarning: Agent 577 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_macro, pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 578 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 579 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:117: UserWarning: Agent 580 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu,pos=pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 581 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 582 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 583 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 584 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 585 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 586 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 587 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 588 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 589 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 590 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 591 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 592 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)
# /tmp/ipykernel_228528/910502594.py:99: UserWarning: Agent 593 is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(new_mu, pos)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math


import mesa
from mesa.datacollection import DataCollector
from mesa import Model
from mesa.space import MultiGrid
from mesa.experimental.cell_space import CellAgent, FixedAgent, OrthogonalVonNeumannGrid
from mesa.experimental.devs import ABMSimulator
from mesa.visualization import Slider, SolaraViz, make_plot_component, make_space_component

# %%
#this cell is used for the base class of bronchial
class Bronchial(FixedAgent):
    def __init__(self, model, pos, init_health =100): #put in all the baseline values we want,
        super().__init__(model)
        self.init_health = init_health #initial health of bronchial
        self.health = init_health
        self.pos = pos
        #self.schedule_event(self.replacement, at=7.0)
    #def placement(self):

    #healing rate mechanism
    def healing(self):
        for obj in self.cell.neighborhood:
            bound_bacteria=False
            for obj in cell.agents:
                if isinstance(obj,Pathogen):
                    bound_bacteria=True
                    break
        if (bound_bacteria==False) and (self.health<(self.init_health/2)):
            self.health+=1

    #replenisment rate mechanism
    def replacement(self):
        #find how long it takes to replace itself
        for cell in self.cell.neighborhood: #looks at all the neighbooring cells
            bound_bacteria=False
            for obj in cell.agents: #looks at all the agents in a cell like they were a list
                if isinstance(obj,Pathogen):
                    bound_bacteria=True
                    break
        if (bound_bacteria==False) and self.health>(self.init_health*.75):
            self.new_pos = (self.pos[0]+1,self.pos[1])
            self.__class__(self.model,self.cell,self.health,self.new_pos)

    # def call_macro(self): #function to call macrophages from bloodstream in cell injury
    #     all_macrophages = list(self.model.agents_by_type[Macrophage])
    #     add_mac= 0
    #     if self.init_health > 75: 
    #         for m in all_macrophages: #note this is a temporary thing to see if the code is working, idk if itll stay init or not and the sign should be flipped
    #             x = self.random.randrange(self.model.grid.width)
    #             y = self.random.randrange(2)
    #             new_macro = Macrophage(self.model, (x,y), m.cell, m.health, m.strength, m.macrophage_gain, m.p_rep)
    #             self.model.grid.place_agent(new_macro, (x,y))
    #             add_mac += 1
    #             if add_mac >6:
    #                 return 
    
    def call_macro(self): #function to call macrophages from bloodstream in cell injury
        all_macrophages = list(self.model.agents_by_type[Macrophage])
        for m in all_macrophages: #note this is a temporary thing to see if the code is working, idk if itll stay init or not and the sign should be flipped
            x = self.random.randrange(self.model.grid.width)
            y = self.random.randrange(2)
            new_macro = Macrophage(self.model, (x,y), m.cell, m.health, m.strength, m.macrophage_gain, m.p_rep)
            self.model.grid.place_agent(new_macro, (x,y))
            return
                

    #what happens each step
    def step(self):
        if self.health < 75:
            self.call_macro()
        #if health <= 0: #cell death
            #self.remove()
        #elif health <= #value for it to trigger healing? which in turns calls mucus:
        if self.model.step_count%2==0:
            self.call_macro()

# %%
#this cell is used for the base class of the bacteria and biofilm

class Pathogen(CellAgent):
    def __init__(self, model, pos, cell, health = 100, strength = 10, bacteria_gain= 10, p_rep = 0.04, p_unstick = 0.04, biof_formed = False):
        super().__init__(model)
        self.pos = pos
        self.cell = cell
        self.health = health #lifespan of pathogen
        self.strength = strength #how much damage it deals to brocnhial
        self.bacteria_gain = bacteria_gain #how much "health" bacteria gains from bronchiol damage
        self.p_rep = p_rep #probability to trigger reproduction
        self.p_unstick = p_unstick #probability of bacteria in biofilm to "unstick" from biofilm
        self.biof_formed = biof_formed #if the specific bacteria is part of the biofilm or not


    #movement - random, limited by mucus, but evasion of macrophages
    def move_bacteria(self):
        self.model.grid.move_agent(self, (self.pos[0],self.pos[1]+1))

    #damaging the bronchiol - cell loses healt, brionchial gains health
    def atk_bacteria(self):
        return
        bronchiol_present = lambda cell: any(isinstance(obj, Bronchial) for obj in cell.agent)
        if bronchiol_present.available:
            self.health += bacteria_gain
            Bronchial.health -=self.strength
            #


    #biofilm formation upon contact with other bacteria
    def biofilm_formation(self):
        return
        #idea before implementation - model biofilm by just makeing them stick to each other and then increasing the health by a certain ffactor when x amount is present and maybe
        #we can also model it to have a certain step strength in a random direction that will decrease the more are connected? and we can have antibiotic deal damage exactly as large as the health or say it insta kills it vs deald this mich dMG when not insta kill
        #model prob of unstick with liek if random is (p sunstick then it will detach)
        bacteria_present = lambda cell: any(isinstance(obj, Pathogen)for obj in cell.agent)

        #code to model bacteria stikcing together in biofilm
        if bacteria.present.available and (self.biof_formed == False):
            #insert code here lol
            self.biof_formed = True

        #probability of bacteria to stop sticking to biofilm
        if (self.biof_formed== True) and (self.random.random() < self.p_unstick):
            #insert code here lol
            self.biof_formed = False




    #reproduction rate of bacteria
    def spawn_offspring(self):
        #using half of its health, it can spawn offspring
        self.health /= 2
        new_bac= Pathogen(self.model, self.pos, self.cell,self.health, self.bacteria_gain, p_rep)
        #self.model.grid.place_agent(new_bac, self.pos)


    #what happens each step
    def step_bacteria(self):
        self.move_bacteria()
        self.biofilm_formation()
        self.atk_bacteria()
        #bacterial death or reproduction
        if self.health < 0:
            return
            #self.remove()
        elif self.random.random() < self.p_rep :
            self.spawn_offspring()

# %%
#this cell is used for the base class of the mucus
class Mucin(CellAgent):
    def __init__(self, model, pos, cell = None):
        super().__init__(model)
        self.pos = pos
        self.cell = cell
    #mucus acts as a medium for the antibiotics, pathogens, and macrophages to travel


    #production of mucins from bottom layer of mucus
    def production(self):
        #get information on status of brionchial
        neighbor = self.model.grid.get_neighbors(self.pos, False)
        for obj in neighbor:# mucin is not being placed as agent
            if isinstance(obj,Bronchial): #im thinking that to time things create different def for each type of production caus ethe conditional only worked in step
                if obj.health > 75: #first injury secretion
                    new_mu = Mucin(self.model, self.pos, self.cell)
                    self.model.grid.place_agent(new_mu, self.pos)


                elif obj.health < 50: #increased secretion
                    self.__class__(self.model, self.pos, self.cell)
                    self.__class__(self.model, self.pos, self.cell)

                elif obj.health < 25: #max secretion
                    self.__class__(self.model)
                    self.__class__(self.model)
                    self.__class__(self.model)

        #ensure mucus is in one layer
        neighborm = self.model.grid.get_neighbors(self.pos, False,include_center = True, radius = 0)
        mucus_positioning = any(isinstance(obj, Mucin) for obj in neighborm)
        #while mucus_positioning

        self.model.grid.move_agent(self, (self.pos[0],self.pos[1]+1)) # it is moving up regarless of if there is a u cin
        mucus_positioning = any(isinstance(obj, Mucin) for obj in neighborm)


    #movement of mucus through cilia
    def move_cilia(self):
        #idea for this specific string of code is to remove itself if it is at the boundary, i think theres a way to do it with reference to how i did the model spawning code
        #each step it will move ____(1), and remove those past bc
        self.model.grid.move_agent(self, (self.pos[0]-1,self.pos[1]))
    #     if self.is_at_boundary():
    #         self.model.grid.remove_agent(self) # this is the specific code that wouldnt work, it might be the if statement
        #cilia_mu = Mucin(self.model, self.pos, self.cell)


        #after cilia pushes, muscin will try to spread out randomly/ normal level muscin will replenish
        #insert code for random 2d movemtn
        #boundary past = .remove


        #note that we also need to add code here that spanws the mucin either here or up in prodcution (spawns on the very right, as in cilia is pushin it into the model?)

    #clearance of mucus through cough - fix oth movements to moveout and get deletdtt
    def move_cough(self):
        #define how much "agents" get moved in one cough, needs same clearance boundaries as move cilia
        if self.model.random.random() < 0.5:

            self.model.grid.move_agent(self, (self.pos[0]-2, self.pos[1]))

    #mucus thinner properties initialized here as timestop of mucus viscosity(???_)

    #what happens each step
    def step(self):
        #movement of mucus
        self.move_cilia()
        self.move_cough()
        if self.model.step_count%2==0 and self.random.random()<.7:
            self.production()

# %%
#this cell is used for the base class of the macrophage
class Macrophage(CellAgent):
    def __init__(self, model, pos, cell=None, health = 20,strength = 20, macrophage_gain= 15, p_rep = 0.04):
        super().__init__(model)
        self.pos = pos
        self.cell = cell
        self.health = health
        self.strength = strength
        self.macrophage_gain = macrophage_gain
        self.p_rep = p_rep

    #movement - aims for the bacteria
    def move_macrophage(self):
        #macrophage will move within mucin
        pathogen_found = self.cell.neighborhood.select(
            lambda cell: any(isinstance(obj, Salmonella) for obj in cell.agents)
        )
        #do we want random movement? if yes, i think this needs to go in a diff if, else line
        target_pathogen = pathogen_found if len(pathogen_found) > 0 else self.cell.neighborhood
        self.cell = target_pathogen.select_random_cell()

    def spawn_rep(self): #mechanism for macrophages to increase through replication
        pass



    #what happens each step
    def step(self):
        #self.move_macrophage()
        self.health -=1 #will moving and cntact decrease health?
        #remove when health is 0
        #reproduction mechanism

# %%
#this cell is used for the base class of antibiotics
class Antibiotic(CellAgent):
    def __init__(self, model,pos, health = 15, strength = 10,):
        super().__init__(model)
        self.pos = pos
        self.health = health
        self.strength = strength

    def move_anti(self):
        pass

    def step(self):
        self.move_anti()
        self.health -= 1 #in this case this is how long it lasts in the body
        #cell remobe here when health is gone
        #reproduction mechanism

# %%
#this cell is used for the creation of the model, which creates the grid
class LungModel(Model):
    def __init__(self, width=20, height=20, init_health_Bronchial=100, seed=100, simulator=None):
        super().__init__(seed=seed)
        self.simulator = simulator
        self.simulator.setup(self)
        self.grid = MultiGrid(width, height, torus=True)
        self.step_count=0
        reporters = {
            "Mucin": lambda m: len(m.agents_by_type[Mucin]),
            "Bronchial": lambda m: len(m.agents_by_type[Bronchial]),
            "Pathogen": lambda m: len(m.agents_by_type[Pathogen]),
            "Antibiotic": lambda m: len(m.agents_by_type[Antibiotic]),
            "Macrophage": lambda m: len(m.agents_by_type[Macrophage])

        }
        self.datacollector = DataCollector(reporters)


#set the fixed position of the bronchial layer
        for x in range(width):
            epithelial=Bronchial(
                self,
                (x,2),
                init_health = init_health_Bronchial,
                ) #makes 20 of the bronchial, the ali form makes batches of randomly placed
            self.grid.place_agent(epithelial, (x,2))

        self.total_mucin = 0
        while self.total_mucin != 50:
            for y in range(3,5):
                x = self.random.randrange(self.grid.width)
                mucus_layer= Mucin(self,(x,y),cell= None,)
                self.total_mucin+=1 #ramdon placement within first line
                self.grid.place_agent(mucus_layer,(x,y))


        total_bact = 0
        total_macro = 0
        while total_bact != 10 : #code to spawn the bacteria within bounds of mucus
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            if any(isinstance(agent, Mucin) for agent in self.grid[x][y]):
                total_bact+=1
                bacteria = Pathogen(
                    self,
                    cell =None,
                    pos = (x,y),
                    health = 100,
                    strength = 10,
                    bacteria_gain= 10,
                    p_rep = 0.04,
                    p_unstick = 0.04,
                    biof_formed = False,
                    )
                self.grid.place_agent(bacteria, (x,y))

        while total_macro != 5 : #code to spawn the macro within bounds of mucus
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            if any(isinstance(agent, Mucin) for agent in self.grid[x][y]):
                total_macro+=1
                macrophages = Macrophage(
                    self,
                    cell = None,
                    pos = (x,y),
                    health = 20,
                    strength = 20,
                    macrophage_gain = 15,
                    p_rep = 0.04,
                    )
                self.grid.place_agent(macrophages, (x,y))

        for x in range(width):
            antibiotic = Antibiotic(
                self,
                (x,1),
                health = 15,
                strength= 10,
                )
            self.grid.place_agent(antibiotic, (x,1))


# think abt bc for stopping mucus at bronchior

#set the initial position of antibiotics


    def step(self):
        self.step_count+=1
        self.agents_by_type[Bronchial].shuffle_do("step")
        self.agents_by_type[Mucin].shuffle_do("step")
        self.agents_by_type[Pathogen].shuffle_do("step")
        self.agents_by_type[Antibiotic].shuffle_do("step")
        self.agents_by_type[Macrophage].shuffle_do("step")
        self.datacollector.collect(self)

# %%
# Styling for visualization
AGENT_COLORS = {
    "Bronchial": "#FD7D7B",
    "Mucin": "green",
    "Pathogen": "blue",
    "Antibiotic": "black",
    "Macrophage": "purple"
}

# Change these parameters to experiment with the model!
MODEL_PARAMETERS = {
    "width": 20, # Grid width
    "height": 20, # Grid height
    #this is wher eu would put the parameter s(if we had any)
    "bronchial_init_health": 100, # heaalth of bironchil
    "seed": 100, # Random seed for reproducibility
}
def lung_portrayal(agent):
    if agent is None:
        return
    p = {"size": 25}
    if isinstance(agent, Mucin):
        p.update({"color": AGENT_COLORS["Mucin"], "marker": "o", "zorder": 3, "size": 45}) #zorder = positioning of whihc is the tip layer
    elif isinstance(agent, Bronchial):
        p.update({"color": AGENT_COLORS["Bronchial"], "marker": "o", "zorder": 60})
    elif isinstance(agent, Pathogen):
        p.update({"color": AGENT_COLORS["Pathogen"], "marker": "o", "zorder": 4, "size" : 25})
    elif isinstance(agent, Antibiotic):
        p.update({"color": AGENT_COLORS["Antibiotic"], "marker": "o", "zorder": 4, "size" : 25})
    elif isinstance(agent, Macrophage):
        p.update({"color": AGENT_COLORS["Macrophage"], "marker": "o", "zorder": 4, "size" : 25})

    return p

model_params = {
    "width": 20,
    "height": 20,
    "bronchial_init_health": Slider("Initial Health of Bronchiol", MODEL_PARAMETERS["bronchial_init_health"], 10, 300),
}

simulator = ABMSimulator()
model_instance = LungModel(simulator=simulator)
space_component = make_space_component(lung_portrayal, draw_grid=True)
lineplot_component = make_plot_component({
    "Bronchial": AGENT_COLORS["Bronchial"],
    "Mucin": AGENT_COLORS["Mucin"],
    "Pathogen": AGENT_COLORS["Pathogen"],
    "Antibiotic": AGENT_COLORS["Antibiotic"],
    "Macrophage": AGENT_COLORS["Macrophage"]
})

page = SolaraViz(
    model_instance,
    components=[space_component, lineplot_component],
    model_params=model_params,
    simulator=simulator,
)
page
# Out:
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (10, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (13, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (14, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (15, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (16, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (17, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (19, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# Cannot show ipywidgets in text

# %%
import matplotlib.pyplot as plt

# Change these parameters to experiment with the model!
MODEL_PARAMETERS = {
    "width": 20, # Grid width
    "height": 20, # Grid height
    #this is wher eu would put the parameter s(if we had any)
    "init_health_Bronchial": 100, # heaalth of bironchil
    "seed": 100, # Random seed for reproducibility
}

# Change this value to run the simulation for more or fewer steps
steps_to_run = 10

print(f"Running simulation for {steps_to_run} steps...")

backup_simulator = ABMSimulator()

# New model instance separate from the one used in the SolaraViz
backup_model = LungModel(
    simulator=backup_simulator,
    **MODEL_PARAMETERS
)

# for _ in range(steps_to_run):
#     backup_model.step()

backup_simulator.run_for(steps_to_run)

df = backup_model.datacollector.get_model_vars_dataframe()

plt.figure(figsize=(12, 6))

plt.plot(df.index, df["Mucin"], color=AGENT_COLORS["Mucin"], label="Mucin", linewidth=2.5)
plt.plot(df.index, df["Bronchial"], color=AGENT_COLORS["Bronchial"], label="Bronchiol", linewidth=2.5)
plt.plot(df.index, df["Pathogen"], color=AGENT_COLORS["Pathogen"], label="Pathogen", linewidth=2.5)
plt.plot(df.index, df["Macrophage"], color=AGENT_COLORS["Macrophage"], label="Macrophage", linewidth=2.5)
plt.plot(df.index, df["Antibiotic"], color=AGENT_COLORS["Antibiotic"], label="Antibiotic", linewidth=2.5)


# Formatting
plt.title("Gut Infection ABM: Population Dynamics")
plt.xlabel("Time (Steps)")
plt.ylabel("Population Count")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1)) # Puts legend outside the plot
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Display the plot
plt.show()

# TIP: To save this image for your PDF, right-click the plot and select "Save image as..."
# Alternatively, uncomment the line below to save it directly to your folder:
# plt.savefig("my_time_series.png", dpi=300)
# Out:
# Running simulation for 10 steps...
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 1 is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 2 is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 3 is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 4 is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 5 is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 6 is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 7 is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 8 is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 9 is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 10 is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 11 is being placed with
# place_agent() despite already having the position (10, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 12 is being placed with
# place_agent() despite already having the position (11, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 13 is being placed with
# place_agent() despite already having the position (12, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 14 is being placed with
# place_agent() despite already having the position (13, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 15 is being placed with
# place_agent() despite already having the position (14, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 16 is being placed with
# place_agent() despite already having the position (15, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 17 is being placed with
# place_agent() despite already having the position (16, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 18 is being placed with
# place_agent() despite already having the position (17, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 19 is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:27: UserWarning: Agent 20 is being placed with
# place_agent() despite already having the position (19, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(epithelial, (x,2))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 21 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 22 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 23 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 24 is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 25 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 26 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 27 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 28 is being placed with
# place_agent() despite already having the position (16, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 29 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 30 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 31 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 32 is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 33 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 34 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 35 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 36 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 37 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 38 is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 39 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 40 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 41 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 42 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 43 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 44 is being placed with
# place_agent() despite already having the position (11, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 45 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 46 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 47 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 48 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 49 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 50 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 51 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 52 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 53 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 54 is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 55 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 56 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 57 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 58 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 59 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 60 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 61 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 62 is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 63 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 64 is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 65 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 66 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 67 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 68 is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 69 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:35: UserWarning: Agent 70 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(mucus_layer,(x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 71 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 72 is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 73 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 74 is being placed with
# place_agent() despite already having the position (13, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 75 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 76 is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 77 is being placed with
# place_agent() despite already having the position (14, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 78 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 79 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:56: UserWarning: Agent 80 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(bacteria, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 81 is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 82 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 83 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 84 is being placed with
# place_agent() despite already having the position (12, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:72: UserWarning: Agent 85 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(macrophages, (x,y))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 86 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 87 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 88 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 89 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 90 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 91 is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 92 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 93 is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 94 is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 95 is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 96 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 97 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 98 is being placed with
# place_agent() despite already having the position (12, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 99 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 100 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 101 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 102 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 103 is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 104 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/364817727.py:81: UserWarning: Agent 105 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(antibiotic, (x,1))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 106 is being placed with
# place_agent() despite already having the position (13, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 107 is being placed with
# place_agent() despite already having the position (12, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 108 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 109 is being placed with
# place_agent() despite already having the position (11, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 110 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 111 is being placed with
# place_agent() despite already having the position (14, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 112 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 113 is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 114 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 115 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 116 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 117 is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 118 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 119 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 120 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 121 is being placed with
# place_agent() despite already having the position (11, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 122 is being placed with
# place_agent() despite already having the position (10, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 123 is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 124 is being placed with
# place_agent() despite already having the position (16, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 125 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 126 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 127 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 128 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 129 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 130 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 131 is being placed with
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 132 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 133 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 134 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 135 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 136 is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 137 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 138 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 139 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 140 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 141 is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 142 is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 143 is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 144 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 145 is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 146 is being placed with
# place_agent() despite already having the position (14, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 147 is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 148 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 149 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 150 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 151 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 152 is being placed with
# place_agent() despite already having the position (19, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 153 is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 154 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 155 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 156 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 157 is being placed with
# place_agent() despite already having the position (15, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 158 is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 159 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 160 is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 161 is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 162 is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 163 is being placed with
# place_agent() despite already having the position (13, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 164 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# ...
# place_agent() despite already having the position (12, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 243 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 244 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 245 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 246 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 247 is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 248 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 249 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 250 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 251 is being placed with
# place_agent() despite already having the position (11, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 252 is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 253 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 254 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 255 is being placed with
# place_agent() despite already having the position (16, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 256 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 257 is being placed with
# place_agent() despite already having the position (10, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 258 is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 259 is being placed with
# place_agent() despite already having the position (14, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 260 is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 261 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 262 is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 263 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 264 is being placed with
# place_agent() despite already having the position (15, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 265 is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 266 is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 267 is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 268 is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 269 is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 270 is being placed with
# place_agent() despite already having the position (10, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 271 is being placed with
# place_agent() despite already having the position (19, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 272 is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 273 is being placed with
# place_agent() despite already having the position (17, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 274 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 275 is being placed with
# place_agent() despite already having the position (13, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/1271675727.py:54: UserWarning: Agent 276 is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_macro, (x,y))
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 277 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 278 is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 279 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 280 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 281 is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 282 is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 283 is being placed with
# place_agent() despite already having the position (14, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 284 is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 285 is being placed with
# place_agent() despite already having the position (16, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 286 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 287 is being placed with
# place_agent() despite already having the position (10, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 288 is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 289 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 290 is being placed with
# place_agent() despite already having the position (16, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 291 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 292 is being placed with
# place_agent() despite already having the position (15, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 293 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 294 is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
# /tmp/ipykernel_43095/622001641.py:18: UserWarning: Agent 295 is being placed with
# place_agent() despite already having the position (8, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.model.grid.place_agent(new_mu, self.pos)
